# %% [markdown]
# https://stepik.org/lesson/296614/step/13?unit=278348

# %% [markdown]
# У Васи есть n пар носков. Утром каждого дня, собираясь в школу, Вася должен надеть пару носков. Вечером, прийдя со школы, Вася снимает надетые носки и выбрасывает их. Каждый m-й день (в дни с номерами m, 2m, 3m, ...) мама покупает Васе одну пару носков. Она делает это поздно вечером, поэтому Вася может надеть новые носки не раньше следующего дня. На сколько подряд идущих дней Васе хватит носков?

# %%
cur_pairs_amount=2
day_num=1

while cur_pairs_amount>0:
  print(cur_pairs_amount)
  day_num+=1
  cur_pairs_amount-=1
# Out:
# 2
# 1

# %%
# cur_pairs_amount=2
# day_num=1

# while cur_pairs_amount-day_num>0:
#   print(cur_pairs_amount)
#   day_num+=1
#   cur_pairs_amount-=day_num
# Out:
# 2

# %%
cur_pairs_amount=9
update_frequency=3

# %%
day_num=1
mother_update_amount=1


while cur_pairs_amount>0:
  print(cur_pairs_amount,day_num)
  day_num+=1
  cur_pairs_amount-=1
  if cur_pairs_amount==0:
    while mother_update_amount>0:
      mother_update_amount-=1
      update_frequency+=update_frequency

  # if cur_pairs_amount==0:
  #    cur_pairs_amount+=mother_update_amount
# Out:
# 9 1
# 8 2
# 7 3
# 6 4
# 5 5
# 4 6
# 3 7
# 2 8
# 1 9

# %%
start=9
b=0
c=0
e=0
for i in range(1,14,1):
  if i%3==0:
    b=i+1
    c+=1
    e+=c
  start-=1 
  print(i,b,c,e,start)
# Out:
# 1 0 0 0 8
# 2 0 0 0 7
# 3 4 1 1 6
# 4 4 1 2 5
# 5 4 1 3 4
# 6 7 2 5 3
# 7 7 2 7 2
# 8 7 2 9 1
# 9 10 3 12 0
# 10 10 3 15 -1
# 11 10 3 18 -2
# 12 13 4 22 -3
# 13 13 4 26 -4

# %%
# не могу понять как увиличть тогда когда start_amount = 0 на величину to_update_amount
# _каждый_последующий_день_уменьшается_n_на_1_и_каждый_m_день_пополняется_на_1
start_amount=9
to_update_amount=0
for i in range(1,14,1):
  day_num_update=0
  frequency=0
  
  if i%3==0:
    day_num_update=i+1
    frequency=frequency+1
    to_update_amount+=frequency
  start_amount-=1 
  print(i,day_num_update,frequency,to_update_amount,start_amount)
# Out:
# 1 0 0 0 8
# 2 0 0 0 7
# 3 4 1 1 6
# 4 0 0 1 5
# 5 0 0 1 4
# 6 7 1 2 3
# 7 0 0 2 2
# 8 0 0 2 1
# 9 10 1 3 0
# 10 0 0 3 -1
# 11 0 0 3 -2
# 12 13 1 4 -3
# 13 0 0 4 -4

# %%
# не могу понять как увиличть тогда когда start_amount = 0 на величину to_update_amount
# _каждый_последующий_день_уменьшается_n_на_1_и_каждый_m_день_пополняется_на_1
def fun(start_amount,freq):
  to_update_amount=0
  for i in range(1,14,1):
    day_num_update=0
    if i%freq==0:
      start_amount+=1
    start_amount-=1 
    print(i,start_amount)


fun(9,3)
# Out:
# 1 8
# 2 7
# 3 7
# 4 6
# 5 5
# 6 5
# 7 4
# 8 3
# 9 3
# 10 2
# 11 1
# 12 1
# 13 0

# %%
# не могу понять как увиличть тогда когда start_amount = 0 на величину to_update_amount
# _каждый_последующий_день_уменьшается_n_на_1_и_каждый_m_день_пополняется_на_1
def fun(start_amount,freq):
  to_update_amount=0
  i=0
  while start_amount>0:
    day_num_update=0
    if i%freq==0:
      start_amount+=1
    i+=1
    start_amount-=1 
    print(i-1,start_amount)


fun(9,3)
# Out:
# 0 9
# 1 8
# 2 7
# 3 7
# 4 6
# 5 5
# 6 5
# 7 4
# 8 3
# 9 3
# 10 2
# 11 1
# 12 1
# 13 0

# %%
# put your python code here
def fun(start_amount,freq):
  to_update_amount=0
  i=0
  while start_amount>0:
    day_num_update=0
    if i%freq==0:
      start_amount+=1
    i+=1
    start_amount-=1 
  print(i-1)

x,y=map(int,input().split())
fun(x,y)
# Out:
# 9 3
# 13
